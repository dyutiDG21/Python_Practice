# %% [markdown]
# # Intermediate Python Practice Exercises (Notebook)
#
# **Estimated time:** ~9 hours (part of the ~14 hour intermediate level, alongside `python-intermediate-guide.ipynb`).
#
# These exercises match the topics in `python-intermediate-guide.ipynb`.
#
# ## How to Use This Notebook
#
# - Read the instructions in each markdown cell.
# - Write your solution in the empty code cell below it, then run it with **Shift + Enter**.
# - Where a cell includes `assert` checks, your solution is correct when the cell runs without an `AssertionError`.
# - Try each exercise yourself before looking up the answer.

# %% [markdown]
# ## Exercise 1: Comprehensions
#
# 1. Build a list of the cubes of numbers 1 through 10.
# 2. Build a list of numbers 1 to 30 that are divisible by 3.
# 3. Build a dict mapping each word in `["red", "green", "blue"]` to its length.
# 4. Given `matrix = [[1, 2], [3, 4], [5, 6]]`, build a flat list of all values using a nested comprehension.

# %%
matrix = [[1, 2], [3, 4], [5, 6]]
# Your code here

# %% [markdown]
# ## Exercise 2: Generators
#
# 1. Write a generator function `evens(limit)` that yields even numbers from 0 up to (but not including) `limit`.
# 2. Use it to print the first even numbers below 10.
# 3. Write a generator expression that yields the squares of 0..9 and pass it to `sum()`.
#
# The asserts below should pass.

# %%
# Your code here

assert list(evens(10)) == [0, 2, 4, 6, 8]
print("OK")

# %% [markdown]
# ## Exercise 3: *args, **kwargs, and Unpacking
#
# 1. Write a function `summarize(*args, **kwargs)` that returns a tuple of `(sum of args, number of kwargs)`.
# 2. Use extended unpacking to assign the first and last elements of `[10, 20, 30, 40]` to `first` and `last`, collecting the middle.
# 3. Merge `{"a": 1, "b": 2}` and `{"b": 3, "c": 4}` into one dict (later values win).

# %%
# Your code here

assert summarize(1, 2, 3, x=1, y=2) == (6, 2)
print("OK")

# %% [markdown]
# ## Exercise 4: Closures
#
# Write a function `make_counter()` that returns a function. Each time the returned function is called, it returns the next integer starting from 1 (1, 2, 3, ...). Two separate counters must not interfere.

# %%
# Your code here

c1 = make_counter()
c2 = make_counter()
assert [c1(), c1(), c1()] == [1, 2, 3]
assert c2() == 1
print("OK")

# %% [markdown]
# ## Exercise 5: Functional Tools
#
# Given `nums = [1, 2, 3, 4, 5, 6]`:
# 1. Use `map` to build a list of squares.
# 2. Use `filter` to keep only numbers greater than 3.
# 3. Use `functools.reduce` to compute the product of all numbers.
# 4. Use `sorted` with a `key` to sort the words `["bb", "a", "ccc"]` by length.

# %%
from functools import reduce
nums = [1, 2, 3, 4, 5, 6]
# Your code here

# %% [markdown]
# ## Exercise 6: Classes
#
# Write a class `Stack` with methods `push(item)`, `pop()`, `peek()`, and `is_empty()`. `pop` on an empty stack should raise `IndexError`.

# %%
# Your code here

s = Stack()
assert s.is_empty()
s.push(1); s.push(2)
assert s.peek() == 2
assert s.pop() == 2
assert s.pop() == 1
assert s.is_empty()
print("OK")

# %% [markdown]
# ## Exercise 7: Inheritance
#
# Create a base class `Shape` with a method `area()` that raises `NotImplementedError`. Create `Rectangle(width, height)` and `Circle(radius)` subclasses that implement `area()`. Use `super().__init__` where appropriate.

# %%
import math
# Your code here

assert Rectangle(3, 4).area() == 12
assert abs(Circle(1).area() - math.pi) < 1e-9
print("OK")

# %% [markdown]
# ## Exercise 8: Dunder Methods
#
# Write a class `Money` storing an amount in cents. Implement `__repr__`, `__add__` (returns a new `Money`), `__eq__`, and `__lt__` so instances can be added, compared, and sorted.

# %%
# Your code here

assert (Money(150) + Money(50)) == Money(200)
assert sorted([Money(300), Money(100), Money(200)]) == [Money(100), Money(200), Money(300)]
print("OK")

# %% [markdown]
# ## Exercise 9: Property, classmethod, staticmethod
#
# Write a class `Circle2` initialized with a radius. Add:
# - a read-only `@property` `diameter`,
# - a `@classmethod` `from_diameter(d)` alternative constructor,
# - a `@staticmethod` `is_valid_radius(r)` that returns whether `r > 0`.

# %%
# Your code here

assert Circle2(5).diameter == 10
assert Circle2.from_diameter(10).radius == 5
assert Circle2.is_valid_radius(-1) is False
print("OK")

# %% [markdown]
# ## Exercise 10: Custom Exceptions
#
# Define a custom exception `ValidationError`. Write a function `validate_age(age)` that raises `ValidationError` with a helpful message if `age` is negative or greater than 150, and returns the age otherwise. Catch and handle it.

# %%
# Your code here

assert validate_age(30) == 30
try:
    validate_age(-1)
    raise AssertionError("should have raised")
except ValidationError:
    print("OK")

# %% [markdown]
# ## Exercise 11: Type Hints
#
# Write a fully type-hinted function `group_by_parity(numbers: list[int]) -> dict[str, list[int]]` that returns a dict with keys `"even"` and `"odd"` mapping to the matching numbers. Inspect `__annotations__` to confirm the hints.

# %%
# Your code here

assert group_by_parity([1, 2, 3, 4]) == {"even": [2, 4], "odd": [1, 3]}
print(group_by_parity.__annotations__)
print("OK")

# %% [markdown]
# ## Exercise 12: collections
#
# 1. Use `Counter` to find the two most common words in a sentence.
# 2. Use `defaultdict(list)` to group the words `["ant", "bee", "bat", "cat", "cow"]` by their first letter.
# 3. Use a `deque` to implement a simple fixed-size history (max length 3) and show that old items are dropped.

# %%
from collections import Counter, defaultdict, deque
# Your code here

# %% [markdown]
# ## Exercise 13: pathlib and JSON
#
# 1. Create a dict representing a small config (name, version, dependencies list).
# 2. Write it as pretty-printed JSON to `tmp_config.json` using `pathlib.Path`.
# 3. Read it back, parse the JSON, and print one value.
# 4. Delete the file when done.

# %%
import json
from pathlib import Path
# Your code here

# %% [markdown]
# ## Exercise 14: Fix the Mutable Default Bug
#
# The function below has the classic mutable-default-argument bug. Rewrite it so each call without an explicit list starts fresh, then confirm the asserts pass.

# %%
def add_item(item, basket=[]):   # buggy: shared default list
    basket.append(item)
    return basket

# Rewrite add_item below to fix the bug
# Your code here

assert add_item("a") == ["a"]
assert add_item("b") == ["b"]   # must NOT be ['a', 'b']
print("OK")

# %% [markdown]
# ## Exercise 15: Mini Project — Word Frequency Report
#
# Write a function `word_report(text)` that:
# 1. Lowercases the text and splits it into words (ignore punctuation by keeping only letters).
# 2. Counts word frequencies using `collections.Counter`.
# 3. Returns a dict of the 3 most common words to their counts.
#
# Use a comprehension and `Counter` together.

# %%
from collections import Counter
# Your code here

sample = "The cat sat on the mat. The cat is happy, the mat is flat."
print(word_report(sample))

# %% [markdown]
# ## Self-Review Checklist
#
# After finishing, check whether you can do these without looking at the guide:
#
# - Write list/dict/set comprehensions and generator expressions.
# - Use `*args`/`**kwargs` and unpacking confidently.
# - Write closures and use functional tools where they read clearly.
# - Design classes with inheritance, dunder methods, and properties/class/static methods.
# - Define and handle custom exceptions.
# - Add meaningful type hints.
# - Use the `collections` containers.
# - Handle paths and JSON.
# - Recognize and avoid common pitfalls.
#
# When you are comfortable here, move on to `python-advanced-guide.ipynb`.
